# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Generate random input data to train on

# %%
observations=1000
xs=np.random.uniform(low=-20,high=20,size=(observations,1))
zs=np.random.uniform(-20,20,(observations,1))

inputs=np.column_stack((xs,zs))

print(inputs.shape)
# Out:
# (1000, 2)

# %% [markdown]
# # Create target

# %%
noise=np.random.uniform(-1,1,(observations,1))
targets=2*xs-3*zs+5+noise
print(targets.shape)
# Out:
# (1000, 1)

# %% [markdown]
# # Plotting the data

# %%
targets=targets.reshape(observations,)
xs = xs.reshape(observations,)
zs = zs.reshape(observations,)
fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(111,projection='3d')
ax.plot(xs,zs,targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targets')
ax.view_init(azim=100)
plt.show()
targets=targets.reshape(observations,1)

# %% [markdown]
# # Initialize variables

# %%
init_range = 0.1
weights = np.random.uniform(low=-init_range, high=init_range, size=(2, 1))
biases = np.random.uniform(low=-init_range, high=init_range, size=1)
print (weights)
print (biases)
# Out:
# [[ 0.09327077]
#  [-0.09135248]]
# [-0.00830477]

# %%
learning_rate = 0.09

# %% [markdown]
# # Train the model

# %%
for i in range (100):
    outputs=np.dot(inputs, weights)+biases
    deltas=outputs-targets
    
    loss=np.sum(deltas**2)/2/observations
    
    print(loss)
    
    deltas_scaled=deltas/observations
    
    weights=weights-learning_rate*np.dot(inputs.T,deltas_scaled)
    biases=biases-learning_rate*np.sum(deltas_scaled)
# Out:
# 24047704540.51972
# 19919357261.894604
# 16499736723.667055
# 13667173512.230513
# 11320885596.044825
# 9377392521.146395
# 7767545193.322016
# 6434065567.191251
# 5329508704.827825
# 4414574694.374137
# 3656710367.0544796
# 3028951062.3035336
# 2508961270.412222
# 2078244471.0353696
# 1722001045.021128
# 1487480314.4119942
# 8218765359.617016
# 807642465182.0133
# 92706708077252.1
# 1.0684870206160674e+16
# 1.2353162585376538e+18
# 1.432956513143011e+20
# 1.6681288353014253e+22
# 1.9492090847458992e+24
# 2.28666447922146e+26
# 2.693609420090341e+28
# 3.1865135942683617e+30
# 3.786104648690339e+32
# 4.518519553913501e+34
# 5.41677390513645e+36
# 6.522637781312449e+38
# 7.889031585843437e+40
# 9.583087049105179e+42
# 1.1690059234935564e+45
# 1.4318327459010843e+47
# 1.7605789696906347e+49
# 2.1728040432006037e+51
# 2.6908831217119746e+53
# 3.343345322087671e+55
# 4.166586030984274e+57
# 5.207058080570031e+59
# 6.524076007470404e+61
# 8.193405263896797e+63
# 1.03118564707796e+66
# 1.3003166557616107e+68
# 1.6425527721796042e+70
# 2.0781226427046727e+72
# 2.6328984377952337e+74
# 3.33997595362584e+76
# 4.24169780064273e+78
# 5.39224401037434e+80
# 6.860949289440496e+82
# 8.73655084365751e+84
# 1.1132627935569697e+87
# 1.419456764785758e+89
# 1.8108485213903752e+91
# 2.3112647522784073e+93
# 2.951210240849242e+95
# 3.769741356900627e+97
# 4.81686535670474e+99
# 6.156613088568133e+101
# 7.870974135680724e+103
# 1.0064936494686391e+106
# 1.2872940852769764e+108
# 1.6467146570538872e+110
# 2.1068017959145655e+112
# 2.695788221829065e+114
# 3.4498293263352665e+116
# 4.415226986791727e+118
# 5.651277649469244e+120
# 7.233919934155653e+122
# 9.260406213068683e+124
# 1.1855285629461119e+127
# 1.5178066724094768e+129
# 1.943303119713365e+131
# 2.4881802709608234e+133
# 3.1859444168782515e+135
# 4.079507407888677e+137
# 5.223827063522095e+139
# 6.689288840945356e+141
# 8.566036863548868e+143
# 1.0969520833043455e+146
# 1.4047600172682637e+148
# 1.798964257966682e+150
# 2.303817689885363e+152
# 2.950381742057728e+154
# 3.778437802609022e+156
# 4.838935244405139e+158
# 6.197126710791591e+160
# 7.936583603899015e+162
# 1.016433888504892e+165
# 1.3017473670828588e+167
# 1.6671552958659458e+169
# 2.1351429609956173e+171
# 2.734508146010508e+173
# 3.502133308131521e+175
# 4.485255278367699e+177
# 5.744372161309085e+179
# 7.356966323384916e+181
# 9.422272580000179e+183

# %%
print(weights,biases)
# Out:
# [[1.07746185e+92]
#  [7.76267680e+91]] [-3.88549942e+89]

# %% [markdown]
# # Plot the last output vs targets

# %%
plt.plot(outputs,targets)
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
